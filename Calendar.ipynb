# %%
import pandas as pd

# Load specific sheet into a DataFrame
df = pd.read_excel('TST00.xlsx', sheet_name='CALENDAR')

# Select specific column within DataFrame
clndr_data = df['clndr_data']

# Convert the column data to string
clndr_data = clndr_data.astype(str)

# Remove the character with unicode value = 127
clndr_data = clndr_data.replace(chr(127), '')

# Convert Series to one long string
clndr_data_string = ''.join(clndr_data)

# Remove '\x7f' from the string
clndr_data_string = clndr_data_string.replace('\x7f', '')

# Remove spaces from the string
clndr_data_string = clndr_data_string.replace(' ', '')

# %%
clndr_data_string
# Out:
# '(0||CalendarData()((0||DaysOfWeek()((0||1()((0||0(s|07:00|f|17:00)())))(0||2()((0||0(s|07:00|f|17:00)())))(0||3()((0||0(s|07:00|f|17:00)())))(0||4()((0||0(s|07:00|f|17:00)())))(0||5()((0||0(s|07:00|f|17:00)())))(0||6()())(0||7()((0||0(s|07:00|f|17:00)())))))(0||VIEW(ShowTotal|Y)())(0||Exceptions()((0||0(d|44197)((0||0(s|08:00|f|16:00)())))(0||1(d|44979)())(0||2(d|45038)())(0||3(d|45039)())(0||4(d|45040)())(0||5(d|45041)())(0||6(d|45104)())(0||7(d|45105)())(0||8(d|45106)())(0||9(d|45108)())(0||10(d|45192)())(0||11(d|45344)())(0||12(d|45391)())(0||13(d|45392)())(0||14(d|45393)())(0||15(d|45395)())(0||16(d|45458)())(0||17(d|45459)())(0||18(d|45460)())(0||19(d|45461)())(0||20(d|45558)())(0||21(d|45679)())(0||22(d|45710)())(0||23(d|45746)())(0||24(d|45747)())(0||25(d|45748)())(0||26(d|45749)())(0||27(d|45813)())(0||28(d|45815)())(0||29(d|45816)())(0||30(d|45817)())(0||31(d|45923)())(0||32(d|46075)())(0||33(d|46100)())(0||34(d|46102)())(0||35(d|46103)())(0||36(d|46104)())(0||37(d|46168)())(0||38(d|46169)())(0||39(d|46170)())(0||40(d|46172)())(0||41(d|46173)())(0||42(d|46213)((0||0(s|07:00|f|17:00)())))(0||43(d|46288)())(0||44(d|46440)())(0||45(d|46456)())(0||46(d|46457)())(0||47(d|46459)())(0||48(d|46460)())(0||49(d|46524)())(0||50(d|46525)())(0||51(d|46526)())(0||52(d|46527)())(0||53(d|46653)())))))'

# %%
# Find start and end indices of required segment
start = clndr_data_string.find("CalendarData()") + len("CalendarData()")
end = clndr_data_string.rfind("(0||VIEW(ShowTotal|Y)())")

# Extract the segment by slicing the string
segment = clndr_data_string[start:end]
segment
# Out:
# '((0||DaysOfWeek()((0||1()((0||0(s|07:00|f|17:00)())))(0||2()((0||0(s|07:00|f|17:00)())))(0||3()((0||0(s|07:00|f|17:00)())))(0||4()((0||0(s|07:00|f|17:00)())))(0||5()((0||0(s|07:00|f|17:00)())))(0||6()())(0||7()((0||0(s|07:00|f|17:00)())))))'

# %%
new_string = segment[17:-2]
new_string
# Out:
# '((0||1()((0||0(s|07:00|f|17:00)())))(0||2()((0||0(s|07:00|f|17:00)())))(0||3()((0||0(s|07:00|f|17:00)())))(0||4()((0||0(s|07:00|f|17:00)())))(0||5()((0||0(s|07:00|f|17:00)())))(0||6()())(0||7()((0||0(s|07:00|f|17:00)())))'

# %%
import pandas as pd
from datetime import timedelta

# Prepare placeholders
days = ['1', '2', '3', '4', '5', '6', '7']
start_hours = ['00:00'] * 7
end_hours = ['00:00'] * 7

# Start from first day
idx = 0
while idx < len(new_string):
    # Find day
    day = new_string[idx:idx + 1]
    if day in days:
        # Get start and end hour
        start_hours[int(day) - 1] = new_string[idx + 21:idx + 26]
        end_hours[int(day) - 1] = new_string[idx + 30:idx + 35]
    idx += 39  # Proceed to next day

# Add working hours
work_hours = [(datetime.strptime(end, '%H:%M') - datetime.strptime(start, '%H:%M')).seconds // 3600 for start, end in
              zip(start_hours, end_hours)]

# Create data frame
dates = pd.date_range("2024-01-01", "2024-12-31")
df = pd.DataFrame(dates, columns=["Day"])
df["Week_Day"] = df["Day"].dt.dayofweek + 1
df["Julian_Date"] = df["Day"].dt.strftime('%Y%j')
df["Starting_Hour"] = df["Week_Day"].apply(lambda x: start_hours[x - 1])
df["Finishing_Hour"] = df["Week_Day"].apply(lambda x: end_hours[x - 1])
df["Working_Hours"] = df["Week_Day"].apply(lambda x: work_hours[x - 1])
df["Working_Day"] = df["Working_Hours"].apply(lambda x: "Yes" if x > 0 else "No")
df["Day"] = df["Day"].dt.strftime('%d-%m-%Y')

print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 21
#      18     idx += 39  # Proceed to next day
#      20 # Add working hours
# ---> 21 work_hours = [(datetime.strptime(end, '%H:%M') - datetime.strptime(start, '%H:%M')).seconds // 3600 for start, end in
#      22               zip(start_hours, end_hours)]
#      24 # Create data frame
#      25 dates = pd.date_range("2024-01-01", "2024-12-31")
#
# AttributeError: module 'datetime' has no attribute 'strptime'

# %%
import pandas as pd
import datetime

# Prepare placeholders
days = ['1', '2', '3', '4', '5', '6', '7']
start_hours = ['00:00'] * 7
end_hours = ['00:00'] * 7

# Start from first day
idx = 0
while idx < len(new_string):
    # Find day
    day = new_string[idx:idx + 1]
    if day in days:
        # Get start and end hour
        start_hours[int(day) - 1] = new_string[idx + 21:idx + 26]
        end_hours[int(day) - 1] = new_string[idx + 30:idx + 35]
    idx += 39  # Proceed to next day

# Compute working hours
working_hours = [(datetime.datetime.strptime(end, '%H:%M') - datetime.datetime.strptime(start, '%H:%M')).seconds / 3600
                 for start, end in zip(start_hours, end_hours)]

# Build DataFrame for the year 2024
dates = pd.date_range("2024-01-01", "2024-12-31")
df = pd.DataFrame(dates, columns=["Day"])
df["Week_Day"] = df["Day"].dt.dayofweek + 1
df["Julian_Date"] = df["Day"].dt.strftime('%Y%j')
df["Starting_Hour"] = df["Week_Day"].apply(lambda x: start_hours[x - 1])
df["Finishing_Hour"] = df["Week_Day"].apply(lambda x: end_hours[x - 1])
df["Working_Hours"] = df["Week_Day"].apply(lambda x: working_hours[x - 1])
df["Working_Day"] = df["Working_Hours"].apply(lambda x: "Yes" if x > 0 else "No")
df["Day"] = df["Day"].dt.strftime('%d-%m-%Y')

# 292            0.0          No
# 293            0.0          No
# 294            0.0          No
# 295            0.0          No
# 296            0.0          No
# 297            0.0          No
# 298            0.0          No
# 299            0.0          No
# 300            0.0          No
# 301            0.0          No
# 302            0.0          No
# 303            0.0          No
# 304            0.0          No
# 305            0.0          No
# 306            0.0          No
# 307            0.0          No
# 308            0.0          No
# 309            0.0          No
# 310            0.0          No
# 311            0.0          No
# 312            0.0          No
# 313            0.0          No
# 314            0.0          No
# 315            0.0          No
# 316            0.0          No
# 317            0.0          No
# 318            0.0          No
# 319            0.0          No
# 320            0.0          No
# 321            0.0          No
# 322            0.0          No
# 323            0.0          No
# 324            0.0          No
# 325            0.0          No
# 326            0.0          No
# 327            0.0          No
# 328            0.0          No
# 329            0.0          No
# 330            0.0          No
# 331            0.0          No
# 332            0.0          No
# 333            0.0          No
# 334            0.0          No
# 335            0.0          No
# 336            0.0          No
# 337            0.0          No
# 338            0.0          No
# 339            0.0          No
# 340            0.0          No
# 341            0.0          No
# 342            0.0          No
# 343            0.0          No
# 344            0.0          No
# 345            0.0          No
# 346            0.0          No
# 347            0.0          No
# 348            0.0          No
# 349            0.0          No
# 350            0.0          No
# 351            0.0          No
# 352            0.0          No
# 353            0.0          No
# 354            0.0          No
# 355            0.0          No
# 356            0.0          No
# 357            0.0          No
# 358            0.0          No
# 359            0.0          No
# 360            0.0          No
# 361            0.0          No
# 362            0.0          No
# 363            0.0          No
# 364            0.0          No
# 365            0.0          No

# %%
def transform_calendar(clndr_data):
    # Prepare an empty list to collect data
    output = []

    # Iterate over dataframe
    for row in clndr_data:
        # Split the string data
        split_strings = row.split("(0||")

        for split_string in split_strings:
            row_data = {}
            if "DaysOfWeek" in split_string:
                row_data['type'] = "DaysOfWeek"
            elif "Exceptions" in split_string:
                row_data['type'] = "Exceptions"

            if 's|' in split_string and 'f|' in split_string:
                start_time = split_string[split_string.find("s|") + 2:split_string.find("s|") + 6]
                finish_time = split_string[split_string.find("f|") + 2:split_string.find("f|") + 6]

                # Convert string time to datetime.time object
                start_time = datetime.datetime.strptime(start_time, "%H:%M").time()
                finish_time = datetime.datetime.strptime(finish_time, "%H:%M").time()

                row_data['start_time'] = start_time
                row_data['finish_time'] = finish_time

                # Calculate working hours considering the day turn after midnight
                if finish_time > start_time:
                    row_data['working_hours'] = datetime.datetime.combine(datetime.date.today(),
                                                                          finish_time) - datetime.datetime.combine(
                        datetime.date.today(), start_time)
                else:  # the shift ends after midnight
                    row_data['working_hours'] = datetime.datetime.combine(datetime.date.today(),
                                                                          finish_time) + datetime.timedelta(
                        days=1) - datetime.datetime.combine(datetime.date.today(), start_time)

            # Append new row into output list
            output.append(row_data)

    # Convert list of dicts to a DataFrame
    output_df = pd.DataFrame(output)

    return output_df

# %%
new_calendar = transform_calendar(clndr_data)

# %%
new_calendar
# Out:
#           type start_time finish_time   working_hours
# 0          NaN        NaN         NaN             NaT
# 1          NaN        NaN         NaN             NaT
# 2   DaysOfWeek        NaN         NaN             NaT
# 3          NaN        NaN         NaN             NaT
# 4          NaN   07:00:00    17:00:00 0 days 10:00:00
# 5          NaN        NaN         NaN             NaT
# 6          NaN   07:00:00    17:00:00 0 days 10:00:00
# 7          NaN        NaN         NaN             NaT
# 8          NaN   07:00:00    17:00:00 0 days 10:00:00
# 9          NaN        NaN         NaN             NaT
# 10         NaN   07:00:00    17:00:00 0 days 10:00:00
# 11         NaN        NaN         NaN             NaT
# 12         NaN   07:00:00    17:00:00 0 days 10:00:00
# 13         NaN        NaN         NaN             NaT
# 14         NaN        NaN         NaN             NaT
# 15         NaN   07:00:00    17:00:00 0 days 10:00:00
# 16         NaN        NaN         NaN             NaT
# 17  Exceptions        NaN         NaN             NaT
# 18         NaN        NaN         NaN             NaT
# 19         NaN   08:00:00    16:00:00 0 days 08:00:00
# 20         NaN        NaN         NaN             NaT
# 21         NaN        NaN         NaN             NaT
# 22         NaN        NaN         NaN             NaT
# 23         NaN        NaN         NaN             NaT
# 24         NaN        NaN         NaN             NaT
# 25         NaN        NaN         NaN             NaT
# 26         NaN        NaN         NaN             NaT
# 27         NaN        NaN         NaN             NaT
# 28         NaN        NaN         NaN             NaT
# 29         NaN        NaN         NaN             NaT
# 30         NaN        NaN         NaN             NaT
# 31         NaN        NaN         NaN             NaT
# 32         NaN        NaN         NaN             NaT
# 33         NaN        NaN         NaN             NaT
# 34         NaN        NaN         NaN             NaT
# 35         NaN        NaN         NaN             NaT
# 36         NaN        NaN         NaN             NaT
# 37         NaN        NaN         NaN             NaT
# 38         NaN        NaN         NaN             NaT
# 39         NaN        NaN         NaN             NaT
# 40         NaN        NaN         NaN             NaT
# 41         NaN        NaN         NaN             NaT
# 42         NaN        NaN         NaN             NaT
# 43         NaN        NaN         NaN             NaT
# 44         NaN        NaN         NaN             NaT
# 45         NaN        NaN         NaN             NaT
# 46         NaN        NaN         NaN             NaT
# 47         NaN        NaN         NaN             NaT
# 48         NaN        NaN         NaN             NaT
# 49         NaN        NaN         NaN             NaT
# 50         NaN        NaN         NaN             NaT
# 51         NaN        NaN         NaN             NaT
# 52         NaN        NaN         NaN             NaT
# 53         NaN        NaN         NaN             NaT
# 54         NaN        NaN         NaN             NaT
# 55         NaN        NaN         NaN             NaT
# 56         NaN        NaN         NaN             NaT
# 57         NaN        NaN         NaN             NaT
# 58         NaN        NaN         NaN             NaT
# 59         NaN        NaN         NaN             NaT
# 60         NaN        NaN         NaN             NaT
# 61         NaN        NaN         NaN             NaT
# 62         NaN   07:00:00    17:00:00 0 days 10:00:00
# 63         NaN        NaN         NaN             NaT
# 64         NaN        NaN         NaN             NaT
# 65         NaN        NaN         NaN             NaT
# 66         NaN        NaN         NaN             NaT
# 67         NaN        NaN         NaN             NaT
# 68         NaN        NaN         NaN             NaT
# 69         NaN        NaN         NaN             NaT
# 70         NaN        NaN         NaN             NaT
# 71         NaN        NaN         NaN             NaT
# 72         NaN        NaN         NaN             NaT
# 73         NaN        NaN         NaN             NaT

# %%
import pandas as pd
import numpy as np

# Load the calendar data into a DataFrame
calendar_df = pd.read_excel('TST00.xlsx', sheet_name='CALENDAR')

# Find the column index of 'clndr_data'
clndr_data_col = calendar_df.columns.get_loc('clndr_data')

# Initialize an empty DataFrame for Cal_Data
cal_data_columns = ["clndr_id", "Data", "type", "Date", "Hours", "Key"]
cal_data_df = pd.DataFrame(columns=cal_data_columns)

# Counter for the new rows
c = 0

# Iterate over each row in the calendar DataFrame starting from the second row
for i in range(0, len(calendar_df)):
    split_string = calendar_df.iloc[i, clndr_data_col]
    split_target = split_string.split('(0||')
    
    # Create new rows for each split part
    new_rows = pd.DataFrame({
        "clndr_id": [calendar_df.iloc[i, 1]] * len(split_target),
        "Data": split_target
    })
    
    # Append new rows to the Cal_Data DataFrame
    cal_data_df = pd.concat([cal_data_df, new_rows], ignore_index=True)
    c += len(split_target)

# Reset index if needed
cal_data_df.reset_index(drop=True, inplace=True)

# Display the resulting DataFrame
print(cal_data_df)
# Out:
#    clndr_id                           Data type Date Hours  Key
# 0       993                                 NaN  NaN   NaN  NaN
# 1       993            CalendarData()(    NaN  NaN   NaN  NaN
# 2       993            DaysOfWeek()(      NaN  NaN   NaN  NaN
# 3       993                   1()(        NaN  NaN   NaN  NaN
# 4       993  0(s|07:00|f|17:00)())))      NaN  NaN   NaN  NaN
# 5       993                   2()(        NaN  NaN   NaN  NaN
# 6       993  0(s|07:00|f|17:00)())))      NaN  NaN   NaN  NaN
# 7       993                   3()(        NaN  NaN   NaN  NaN
# 8       993  0(s|07:00|f|17:00)())))      NaN  NaN   NaN  NaN
# 9       993                   4()(        NaN  NaN   NaN  NaN
# 10      993  0(s|07:00|f|17:00)())))      NaN  NaN   NaN  NaN
# 11      993                   5()(        NaN  NaN   NaN  NaN
# 12      993  0(s|07:00|f|17:00)())))      NaN  NaN   NaN  NaN
# 13      993                   6()())      NaN  NaN   NaN  NaN
# 14      993                   7()(        NaN  NaN   NaN  NaN
# 15      993  0(s|07:00|f|17:00)())))))    NaN  NaN   NaN  NaN
# 16      993       VIEW(ShowTotal|Y)())    NaN  NaN   NaN  NaN
# 17      993            Exceptions()(      NaN  NaN   NaN  NaN
# 18      993            0(d|44197)(        NaN  NaN   NaN  NaN
# 19      993  0(s|08:00|f|16:00)())))      NaN  NaN   NaN  NaN
# 20      993            1(d|44979)())      NaN  NaN   NaN  NaN
# 21      993            2(d|45038)())      NaN  NaN   NaN  NaN
# 22      993            3(d|45039)())      NaN  NaN   NaN  NaN
# 23      993            4(d|45040)())      NaN  NaN   NaN  NaN
# 24      993            5(d|45041)())      NaN  NaN   NaN  NaN
# 25      993            6(d|45104)())      NaN  NaN   NaN  NaN
# 26      993            7(d|45105)())      NaN  NaN   NaN  NaN
# 27      993            8(d|45106)())      NaN  NaN   NaN  NaN
# 28      993            9(d|45108)())      NaN  NaN   NaN  NaN
# 29      993           10(d|45192)())      NaN  NaN   NaN  NaN
# 30      993           11(d|45344)())      NaN  NaN   NaN  NaN
# 31      993           12(d|45391)())      NaN  NaN   NaN  NaN
# 32      993           13(d|45392)())      NaN  NaN   NaN  NaN
# 33      993           14(d|45393)())      NaN  NaN   NaN  NaN
# 34      993           15(d|45395)())      NaN  NaN   NaN  NaN
# 35      993           16(d|45458)())      NaN  NaN   NaN  NaN
# 36      993           17(d|45459)())      NaN  NaN   NaN  NaN
# 37      993           18(d|45460)())      NaN  NaN   NaN  NaN
# 38      993           19(d|45461)())      NaN  NaN   NaN  NaN
# 39      993           20(d|45558)())      NaN  NaN   NaN  NaN
# 40      993           21(d|45679)())      NaN  NaN   NaN  NaN
# 41      993           22(d|45710)())      NaN  NaN   NaN  NaN
# 42      993           23(d|45746)())      NaN  NaN   NaN  NaN
# 43      993           24(d|45747)())      NaN  NaN   NaN  NaN
# 44      993           25(d|45748)())      NaN  NaN   NaN  NaN
# 45      993           26(d|45749)())      NaN  NaN   NaN  NaN
# 46      993           27(d|45813)())      NaN  NaN   NaN  NaN
# 47      993           28(d|45815)())      NaN  NaN   NaN  NaN
# 48      993           29(d|45816)())      NaN  NaN   NaN  NaN
# 49      993           30(d|45817)())      NaN  NaN   NaN  NaN
# 50      993           31(d|45923)())      NaN  NaN   NaN  NaN
# 51      993           32(d|46075)())      NaN  NaN   NaN  NaN
# 52      993           33(d|46100)())      NaN  NaN   NaN  NaN
# 53      993           34(d|46102)())      NaN  NaN   NaN  NaN
# 54      993           35(d|46103)())      NaN  NaN   NaN  NaN
# 55      993           36(d|46104)())      NaN  NaN   NaN  NaN
# 56      993           37(d|46168)())      NaN  NaN   NaN  NaN
# 57      993           38(d|46169)())      NaN  NaN   NaN  NaN
# 58      993           39(d|46170)())      NaN  NaN   NaN  NaN
# 59      993           40(d|46172)())      NaN  NaN   NaN  NaN
# 60      993           41(d|46173)())      NaN  NaN   NaN  NaN
# 61      993           42(d|46213)(        NaN  NaN   NaN  NaN
# 62      993  0(s|07:00|f|17:00)())))      NaN  NaN   NaN  NaN
# 63      993           43(d|46288)())      NaN  NaN   NaN  NaN
# 64      993           44(d|46440)())      NaN  NaN   NaN  NaN
# 65      993           45(d|46456)())      NaN  NaN   NaN  NaN
# 66      993           46(d|46457)())      NaN  NaN   NaN  NaN
# 67      993           47(d|46459)())      NaN  NaN   NaN  NaN
# 68      993           48(d|46460)())      NaN  NaN   NaN  NaN
# 69      993           49(d|46524)())      NaN  NaN   NaN  NaN
# 70      993           50(d|46525)())      NaN  NaN   NaN  NaN
# 71      993           51(d|46526)())      NaN  NaN   NaN  NaN
# 72      993           52(d|46527)())      NaN  NaN   NaN  NaN
# 73      993             53(d|46653)())))))  NaN  NaN   NaN  NaN

# %%
split_string
# Out:
# '(0||CalendarData()(\x7f\x7f  (0||DaysOfWeek()(\x7f\x7f    (0||1()(\x7f\x7f      (0||0(s|07:00|f|17:00)())))\x7f\x7f    (0||2()(\x7f\x7f      (0||0(s|07:00|f|17:00)())))\x7f\x7f    (0||3()(\x7f\x7f      (0||0(s|07:00|f|17:00)())))\x7f\x7f    (0||4()(\x7f\x7f      (0||0(s|07:00|f|17:00)())))\x7f\x7f    (0||5()(\x7f\x7f      (0||0(s|07:00|f|17:00)())))\x7f\x7f    (0||6()())\x7f\x7f    (0||7()(\x7f\x7f      (0||0(s|07:00|f|17:00)())))))\x7f\x7f  (0||VIEW(ShowTotal|Y)())\x7f\x7f  (0||Exceptions()(\x7f\x7f    (0||0(d|44197)(\x7f\x7f      (0||0(s|08:00|f|16:00)())))\x7f\x7f    (0||1(d|44979)())\x7f\x7f    (0||2(d|45038)())\x7f\x7f    (0||3(d|45039)())\x7f\x7f    (0||4(d|45040)())\x7f\x7f    (0||5(d|45041)())\x7f\x7f    (0||6(d|45104)())\x7f\x7f    (0||7(d|45105)())\x7f\x7f    (0||8(d|45106)())\x7f\x7f    (0||9(d|45108)())\x7f\x7f    (0||10(d|45192)())\x7f\x7f    (0||11(d|45344)())\x7f\x7f    (0||12(d|45391)())\x7f\x7f    (0||13(d|45392)())\x7f\x7f    (0||14(d|45393)())\x7f\x7f    (0||15(d|45395)())\x7f\x7f    (0||16(d|45458)())\x7f\x7f    (0||17(d|45459)())\x7f\x7f    (0||18(d|45460)())\x7f\x7f    (0||19(d|45461)())\x7f\x7f    (0||20(d|45558)())\x7f\x7f    (0||21(d|45679)())\x7f\x7f    (0||22(d|45710)())\x7f\x7f    (0||23(d|45746)())\x7f\x7f    (0||24(d|45747)())\x7f\x7f    (0||25(d|45748)())\x7f\x7f    (0||26(d|45749)())\x7f\x7f    (0||27(d|45813)())\x7f\x7f    (0||28(d|45815)())\x7f\x7f    (0||29(d|45816)())\x7f\x7f    (0||30(d|45817)())\x7f\x7f    (0||31(d|45923)())\x7f\x7f    (0||32(d|46075)())\x7f\x7f    (0||33(d|46100)())\x7f\x7f    (0||34(d|46102)())\x7f\x7f    (0||35(d|46103)())\x7f\x7f    (0||36(d|46104)())\x7f\x7f    (0||37(d|46168)())\x7f\x7f    (0||38(d|46169)())\x7f\x7f    (0||39(d|46170)())\x7f\x7f    (0||40(d|46172)())\x7f\x7f    (0||41(d|46173)())\x7f\x7f    (0||42(d|46213)(\x7f\x7f      (0||0(s|07:00|f|17:00)())))\x7f\x7f    (0||43(d|46288)())\x7f\x7f    (0||44(d|46440)())\x7f\x7f    (0||45(d|46456)())\x7f\x7f    (0||46(d|46457)())\x7f\x7f    (0||47(d|46459)())\x7f\x7f    (0||48(d|46460)())\x7f\x7f    (0||49(d|46524)())\x7f\x7f    (0||50(d|46525)())\x7f\x7f    (0||51(d|46526)())\x7f\x7f    (0||52(d|46527)())\x7f\x7f    (0||53(d|46653)())))))'

# %%
split_target
# Out:
# ['',
#  'CalendarData()(\x7f\x7f  ',
#  'DaysOfWeek()(\x7f\x7f    ',
#  '1()(\x7f\x7f      ',
#  '0(s|07:00|f|17:00)())))\x7f\x7f    ',
#  '2()(\x7f\x7f      ',
#  '0(s|07:00|f|17:00)())))\x7f\x7f    ',
#  '3()(\x7f\x7f      ',
#  '0(s|07:00|f|17:00)())))\x7f\x7f    ',
#  '4()(\x7f\x7f      ',
#  '0(s|07:00|f|17:00)())))\x7f\x7f    ',
#  '5()(\x7f\x7f      ',
#  '0(s|07:00|f|17:00)())))\x7f\x7f    ',
#  '6()())\x7f\x7f    ',
#  '7()(\x7f\x7f      ',
#  '0(s|07:00|f|17:00)())))))\x7f\x7f  ',
#  'VIEW(ShowTotal|Y)())\x7f\x7f  ',
#  'Exceptions()(\x7f\x7f    ',
#  '0(d|44197)(\x7f\x7f      ',
#  '0(s|08:00|f|16:00)())))\x7f\x7f    ',
#  '1(d|44979)())\x7f\x7f    ',
#  '2(d|45038)())\x7f\x7f    ',
#  '3(d|45039)())\x7f\x7f    ',
#  '4(d|45040)())\x7f\x7f    ',
#  '5(d|45041)())\x7f\x7f    ',
#  '6(d|45104)())\x7f\x7f    ',
#  '7(d|45105)())\x7f\x7f    ',
#  '8(d|45106)())\x7f\x7f    ',
#  '9(d|45108)())\x7f\x7f    ',
#  '10(d|45192)())\x7f\x7f    ',
#  '11(d|45344)())\x7f\x7f    ',
#  '12(d|45391)())\x7f\x7f    ',
#  '13(d|45392)())\x7f\x7f    ',
#  '14(d|45393)())\x7f\x7f    ',
#  '15(d|45395)())\x7f\x7f    ',
#  '16(d|45458)())\x7f\x7f    ',
#  '17(d|45459)())\x7f\x7f    ',
#  '18(d|45460)())\x7f\x7f    ',
#  '19(d|45461)())\x7f\x7f    ',
#  '20(d|45558)())\x7f\x7f    ',
#  '21(d|45679)())\x7f\x7f    ',
#  '22(d|45710)())\x7f\x7f    ',
#  '23(d|45746)())\x7f\x7f    ',
#  '24(d|45747)())\x7f\x7f    ',
#  '25(d|45748)())\x7f\x7f    ',
#  '26(d|45749)())\x7f\x7f    ',
#  '27(d|45813)())\x7f\x7f    ',
#  '28(d|45815)())\x7f\x7f    ',
#  '29(d|45816)())\x7f\x7f    ',
#  '30(d|45817)())\x7f\x7f    ',
#  '31(d|45923)())\x7f\x7f    ',
#  '32(d|46075)())\x7f\x7f    ',
#  '33(d|46100)())\x7f\x7f    ',
#  '34(d|46102)())\x7f\x7f    ',
#  '35(d|46103)())\x7f\x7f    ',
#  '36(d|46104)())\x7f\x7f    ',
#  '37(d|46168)())\x7f\x7f    ',
#  '38(d|46169)())\x7f\x7f    ',
#  '39(d|46170)())\x7f\x7f    ',
#  '40(d|46172)())\x7f\x7f    ',
#  '41(d|46173)())\x7f\x7f    ',
#  '42(d|46213)(\x7f\x7f      ',
#  '0(s|07:00|f|17:00)())))\x7f\x7f    ',
#  '43(d|46288)())\x7f\x7f    ',
#  '44(d|46440)())\x7f\x7f    ',
#  '45(d|46456)())\x7f\x7f    ',
#  '46(d|46457)())\x7f\x7f    ',
#  '47(d|46459)())\x7f\x7f    ',
#  '48(d|46460)())\x7f\x7f    ',
#  '49(d|46524)())\x7f\x7f    ',
#  '50(d|46525)())\x7f\x7f    ',
#  '51(d|46526)())\x7f\x7f    ',
#  '52(d|46527)())\x7f\x7f    ',
#  '53(d|46653)())))))']

# %%
# Assume cal_data_df is the DataFrame from the previous section

# Function to classify data
def classify_data(data):
    if "DaysOfWeek" in data:
        return "DaysOfWeek"
    elif "Exceptions" in data:
        return "Exceptions"
    else:
        return np.nan

# Apply the classification function to the Data column
cal_data_df['type'] = cal_data_df['Data'].apply(classify_data)

# Display the resulting DataFrame
print(cal_data_df)
# Out:
#    clndr_id                           Data        type Date Hours  Key
# 0       993                                        NaN  NaN   NaN  NaN
# 1       993            CalendarData()(           NaN  NaN   NaN  NaN
# 2       993            DaysOfWeek()(      DaysOfWeek  NaN   NaN  NaN
# 3       993                   1()(               NaN  NaN   NaN  NaN
# 4       993  0(s|07:00|f|17:00)())))             NaN  NaN   NaN  NaN
# 5       993                   2()(               NaN  NaN   NaN  NaN
# 6       993  0(s|07:00|f|17:00)())))             NaN  NaN   NaN  NaN
# 7       993                   3()(               NaN  NaN   NaN  NaN
# 8       993  0(s|07:00|f|17:00)())))             NaN  NaN   NaN  NaN
# 9       993                   4()(               NaN  NaN   NaN  NaN
# 10      993  0(s|07:00|f|17:00)())))             NaN  NaN   NaN  NaN
# 11      993                   5()(               NaN  NaN   NaN  NaN
# 12      993  0(s|07:00|f|17:00)())))             NaN  NaN   NaN  NaN
# 13      993                   6()())             NaN  NaN   NaN  NaN
# 14      993                   7()(               NaN  NaN   NaN  NaN
# 15      993  0(s|07:00|f|17:00)())))))           NaN  NaN   NaN  NaN
# 16      993       VIEW(ShowTotal|Y)())           NaN  NaN   NaN  NaN
# 17      993            Exceptions()(      Exceptions  NaN   NaN  NaN
# 18      993            0(d|44197)(               NaN  NaN   NaN  NaN
# 19      993  0(s|08:00|f|16:00)())))             NaN  NaN   NaN  NaN
# 20      993            1(d|44979)())             NaN  NaN   NaN  NaN
# 21      993            2(d|45038)())             NaN  NaN   NaN  NaN
# 22      993            3(d|45039)())             NaN  NaN   NaN  NaN
# 23      993            4(d|45040)())             NaN  NaN   NaN  NaN
# 24      993            5(d|45041)())             NaN  NaN   NaN  NaN
# 25      993            6(d|45104)())             NaN  NaN   NaN  NaN
# 26      993            7(d|45105)())             NaN  NaN   NaN  NaN
# 27      993            8(d|45106)())             NaN  NaN   NaN  NaN
# 28      993            9(d|45108)())             NaN  NaN   NaN  NaN
# 29      993           10(d|45192)())             NaN  NaN   NaN  NaN
# 30      993           11(d|45344)())             NaN  NaN   NaN  NaN
# 31      993           12(d|45391)())             NaN  NaN   NaN  NaN
# 32      993           13(d|45392)())             NaN  NaN   NaN  NaN
# 33      993           14(d|45393)())             NaN  NaN   NaN  NaN
# 34      993           15(d|45395)())             NaN  NaN   NaN  NaN
# 35      993           16(d|45458)())             NaN  NaN   NaN  NaN
# 36      993           17(d|45459)())             NaN  NaN   NaN  NaN
# 37      993           18(d|45460)())             NaN  NaN   NaN  NaN
# 38      993           19(d|45461)())             NaN  NaN   NaN  NaN
# 39      993           20(d|45558)())             NaN  NaN   NaN  NaN
# 40      993           21(d|45679)())             NaN  NaN   NaN  NaN
# 41      993           22(d|45710)())             NaN  NaN   NaN  NaN
# 42      993           23(d|45746)())             NaN  NaN   NaN  NaN
# 43      993           24(d|45747)())             NaN  NaN   NaN  NaN
# 44      993           25(d|45748)())             NaN  NaN   NaN  NaN
# 45      993           26(d|45749)())             NaN  NaN   NaN  NaN
# 46      993           27(d|45813)())             NaN  NaN   NaN  NaN
# 47      993           28(d|45815)())             NaN  NaN   NaN  NaN
# 48      993           29(d|45816)())             NaN  NaN   NaN  NaN
# 49      993           30(d|45817)())             NaN  NaN   NaN  NaN
# 50      993           31(d|45923)())             NaN  NaN   NaN  NaN
# 51      993           32(d|46075)())             NaN  NaN   NaN  NaN
# 52      993           33(d|46100)())             NaN  NaN   NaN  NaN
# 53      993           34(d|46102)())             NaN  NaN   NaN  NaN
# 54      993           35(d|46103)())             NaN  NaN   NaN  NaN
# 55      993           36(d|46104)())             NaN  NaN   NaN  NaN
# 56      993           37(d|46168)())             NaN  NaN   NaN  NaN
# 57      993           38(d|46169)())             NaN  NaN   NaN  NaN
# 58      993           39(d|46170)())             NaN  NaN   NaN  NaN
# 59      993           40(d|46172)())             NaN  NaN   NaN  NaN
# 60      993           41(d|46173)())             NaN  NaN   NaN  NaN
# 61      993           42(d|46213)(               NaN  NaN   NaN  NaN
# 62      993  0(s|07:00|f|17:00)())))             NaN  NaN   NaN  NaN
# 63      993           43(d|46288)())             NaN  NaN   NaN  NaN
# 64      993           44(d|46440)())             NaN  NaN   NaN  NaN
# 65      993           45(d|46456)())             NaN  NaN   NaN  NaN
# 66      993           46(d|46457)())             NaN  NaN   NaN  NaN
# 67      993           47(d|46459)())             NaN  NaN   NaN  NaN
# 68      993           48(d|46460)())             NaN  NaN   NaN  NaN
# 69      993           49(d|46524)())             NaN  NaN   NaN  NaN
# 70      993           50(d|46525)())             NaN  NaN   NaN  NaN
# 71      993           51(d|46526)())             NaN  NaN   NaN  NaN
# 72      993           52(d|46527)())             NaN  NaN   NaN  NaN
# 73      993             53(d|46653)())))))         NaN  NaN   NaN  NaN

# %%
from datetime import datetime, timedelta

# Function to extract date and calculate hours
def extract_date_and_hours(row):
    data = row['Data']
    row_type = row['type']
    
    # Initialize date and hours
    date = np.nan
    hours = np.nan

    if row_type == "DaysOfWeek" and data.startswith("()"):
        date = data[1]
    elif row_type == "Exceptions" and "(d|)" in data:
        date = data.split("(d|")[1][:5]

    if "s|" in data and "f|" in data:
        s_index = data.index("s|") + 2
        f_index = data.index("f|") + 2
        start_time_str = data[s_index:s_index + 4]
        end_time_str = data[f_index:f_index + 4]

        # Check if the extracted strings are valid time formats
        if len(start_time_str) == 4 and len(end_time_str) == 4:
            try:
                start_time = datetime.strptime(start_time_str, '%H%M')
                end_time = datetime.strptime(end_time_str, '%H%M')
                if start_time == end_time:
                    hours = 24
                else:
                    hours = (end_time - start_time).seconds / 3600  # Convert to hours
                    if start_time > end_time:
                        hours = 24 - hours
            except ValueError:
                # Handle the case where time conversion fails
                pass

    return pd.Series([date, hours])

# Apply the function to each row
cal_data_df[['Date', 'Hours']] = cal_data_df.apply(extract_date_and_hours, axis=1)

# Fill missing 'type' values with the previous row's 'type'
cal_data_df['type'].fillna(method='ffill', inplace=True)

# Inherit date from previous row if conditions are met
for i in range(1, len(cal_data_df)):
    if pd.isna(cal_data_df.at[i, 'Date']) and cal_data_df.at[i, 'type'] == cal_data_df.at[i-1, 'type'] and \
       cal_data_df.at[i, 'clndr_id'] == cal_data_df.at[i-1, 'clndr_id'] and "VIEW(ShowTotal|Y)" not in cal_data_df.at[i, 'Data']:
        cal_data_df.at[i, 'Date'] = cal_data_df.at[i-1, 'Date']

# Display the resulting DataFrame
print(cal_data_df)
# Out:
#    clndr_id                           Data        type  Date  Hours  Key
# 0       993                                        NaN   NaN    NaN  NaN
# 1       993            CalendarData()(           NaN   NaN    NaN  NaN
# 2       993            DaysOfWeek()(      DaysOfWeek   NaN    NaN  NaN
# 3       993                   1()(        DaysOfWeek   NaN    NaN  NaN
# 4       993  0(s|07:00|f|17:00)())))      DaysOfWeek   NaN    NaN  NaN
# 5       993                   2()(        DaysOfWeek   NaN    NaN  NaN
# 6       993  0(s|07:00|f|17:00)())))      DaysOfWeek   NaN    NaN  NaN
# 7       993                   3()(        DaysOfWeek   NaN    NaN  NaN
# 8       993  0(s|07:00|f|17:00)())))      DaysOfWeek   NaN    NaN  NaN
# 9       993                   4()(        DaysOfWeek   NaN    NaN  NaN
# 10      993  0(s|07:00|f|17:00)())))      DaysOfWeek   NaN    NaN  NaN
# 11      993                   5()(        DaysOfWeek   NaN    NaN  NaN
# 12      993  0(s|07:00|f|17:00)())))      DaysOfWeek   NaN    NaN  NaN
# 13      993                   6()())      DaysOfWeek   NaN    NaN  NaN
# 14      993                   7()(        DaysOfWeek   NaN    NaN  NaN
# 15      993  0(s|07:00|f|17:00)())))))    DaysOfWeek   NaN    NaN  NaN
# 16      993       VIEW(ShowTotal|Y)())    DaysOfWeek   NaN    NaN  NaN
# 17      993            Exceptions()(      Exceptions   NaN    NaN  NaN
# 18      993            0(d|44197)(        Exceptions   NaN    NaN  NaN
# 19      993  0(s|08:00|f|16:00)())))      Exceptions   NaN    NaN  NaN
# 20      993            1(d|44979)())      Exceptions   NaN    NaN  NaN
# 21      993            2(d|45038)())      Exceptions   NaN    NaN  NaN
# 22      993            3(d|45039)())      Exceptions   NaN    NaN  NaN
# 23      993            4(d|45040)())      Exceptions   NaN    NaN  NaN
# 24      993            5(d|45041)())      Exceptions   NaN    NaN  NaN
# 25      993            6(d|45104)())      Exceptions   NaN    NaN  NaN
# 26      993            7(d|45105)())      Exceptions   NaN    NaN  NaN
# 27      993            8(d|45106)())      Exceptions   NaN    NaN  NaN
# 28      993            9(d|45108)())      Exceptions   NaN    NaN  NaN
# 29      993           10(d|45192)())      Exceptions   NaN    NaN  NaN
# 30      993           11(d|45344)())      Exceptions   NaN    NaN  NaN
# 31      993           12(d|45391)())      Exceptions   NaN    NaN  NaN
# 32      993           13(d|45392)())      Exceptions   NaN    NaN  NaN
# 33      993           14(d|45393)())      Exceptions   NaN    NaN  NaN
# 34      993           15(d|45395)())      Exceptions   NaN    NaN  NaN
# 35      993           16(d|45458)())      Exceptions   NaN    NaN  NaN
# 36      993           17(d|45459)())      Exceptions   NaN    NaN  NaN
# 37      993           18(d|45460)())      Exceptions   NaN    NaN  NaN
# 38      993           19(d|45461)())      Exceptions   NaN    NaN  NaN
# 39      993           20(d|45558)())      Exceptions   NaN    NaN  NaN
# 40      993           21(d|45679)())      Exceptions   NaN    NaN  NaN
# 41      993           22(d|45710)())      Exceptions   NaN    NaN  NaN
# 42      993           23(d|45746)())      Exceptions   NaN    NaN  NaN
# 43      993           24(d|45747)())      Exceptions   NaN    NaN  NaN
# 44      993           25(d|45748)())      Exceptions   NaN    NaN  NaN
# 45      993           26(d|45749)())      Exceptions   NaN    NaN  NaN
# 46      993           27(d|45813)())      Exceptions   NaN    NaN  NaN
# 47      993           28(d|45815)())      Exceptions   NaN    NaN  NaN
# 48      993           29(d|45816)())      Exceptions   NaN    NaN  NaN
# 49      993           30(d|45817)())      Exceptions   NaN    NaN  NaN
# 50      993           31(d|45923)())      Exceptions   NaN    NaN  NaN
# 51      993           32(d|46075)())      Exceptions   NaN    NaN  NaN
# 52      993           33(d|46100)())      Exceptions   NaN    NaN  NaN
# 53      993           34(d|46102)())      Exceptions   NaN    NaN  NaN
# 54      993           35(d|46103)())      Exceptions   NaN    NaN  NaN
# 55      993           36(d|46104)())      Exceptions   NaN    NaN  NaN
# 56      993           37(d|46168)())      Exceptions   NaN    NaN  NaN
# 57      993           38(d|46169)())      Exceptions   NaN    NaN  NaN
# 58      993           39(d|46170)())      Exceptions   NaN    NaN  NaN
# 59      993           40(d|46172)())      Exceptions   NaN    NaN  NaN
# 60      993           41(d|46173)())      Exceptions   NaN    NaN  NaN
# 61      993           42(d|46213)(        Exceptions   NaN    NaN  NaN
# 62      993  0(s|07:00|f|17:00)())))      Exceptions   NaN    NaN  NaN
# 63      993           43(d|46288)())      Exceptions   NaN    NaN  NaN
# 64      993           44(d|46440)())      Exceptions   NaN    NaN  NaN
# 65      993           45(d|46456)())      Exceptions   NaN    NaN  NaN
# 66      993           46(d|46457)())      Exceptions   NaN    NaN  NaN
# 67      993           47(d|46459)())      Exceptions   NaN    NaN  NaN
# 68      993           48(d|46460)())      Exceptions   NaN    NaN  NaN
# 69      993           49(d|46524)())      Exceptions   NaN    NaN  NaN
# 70      993           50(d|46525)())      Exceptions   NaN    NaN  NaN
# 71      993           51(d|46526)())      Exceptions   NaN    NaN  NaN
# 72      993           52(d|46527)())      Exceptions   NaN    NaN  NaN
# 73      993             53(d|46653)())))))  Exceptions   NaN    NaN  NaN
# C:\Users\abdra\AppData\Local\Temp\ipykernel_15384\1065328383.py:44: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cal_data_df['type'].fillna(method='ffill', inplace=True)
# C:\Users\abdra\AppData\Local\Temp\ipykernel_15384\1065328383.py:44: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   cal_data_df['type'].fillna(method='ffill', inplace=True)
